# %% [markdown]
# # NIRCam LW data analysis I. Finding calibrated data
#
# In this notebook, we will produce corrected data from `uncal` JWST data.
#
# For stage 1 processing, we will mainly use the `jwst` pipeline with some modifications. The main modification is the use of `refpix` step. Although this dataset _have_ reference pixels on three edges of the detector, some earlier works with ERS data have shown that background subtraction at group level works more efficiently than when it is done at integration level. Therefore, we will perform a group level background subtraction using ROEBA (row-by-row odd/even by amplifier correction, [Schlawin et al. 2023](https://iopscience.iop.org/article/10.1088/1538-3873/aca718)) algorithm in addition to the `refpix` step (see, below).

# %%
import numpy as np
import matplotlib.pyplot as plt
from jwst import datamodels
from jwst.pipeline import calwebb_detector1
from tqdm import tqdm
import os
import utils
from stark import reduce

# %%
p1 = '/'.join(os.getcwd().split('/')[:-1])
pin = p1 + '/Data/NRC_LW'
pout = p1 + '/NRCLW/Outputs/Tests'

fname = 'jw01442001001_04103_00001-seg006_nrcalong_uncal.fits'

# %% [markdown]
# ## calwebb detector 1 processing

# %%
uncal = datamodels.RampModel(pin + '/' + fname)
nint = np.random.randint(0, uncal.data.shape[0])

print(uncal)
# Out:
# <RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>

# %% [markdown]
# Meaning that the data has 65 total integration and 20 groups per integrations. An individual frame has 128 by 2048 pixels (128 rows and 2048 columns). Let's first visualise the data.

# %%
plt.figure(figsize=(15,5))
im = plt.imshow(uncal.data[nint,-1,:,:], interpolation='none')
im.set_clim([0,2e4])
plt.title('Example data')
# Out:
# Text(0.5, 1.0, 'Example data')

# %% [markdown]
# Let's perform `groupscale`, `dq`, `saturation` and `superbias` steps manually.

# %%
"""det1 = calwebb_detector1.Detector1Pipeline.call(uncal,\
                                                steps={'jump' : {'rejection_threshold' : 20., 'maximum_cores': 'all'},\
                                                       'dark_current' : {'skip' : True},\
                                                       'ramp_fit' : {'maximum_cores' : 'all'}},\
                                                output_dir=pout, save_results=True)"""

# I tried running the pipeline collectively, but it turns out that the jump step was flagging many pixels
# wrongly; maybe this is because of improper reference pixel correction step -- so now, I will manually perform
# this step using ROEBA algorithm.

groupscale_results = calwebb_detector1.group_scale_step.GroupScaleStep.call(uncal, save_results=False)
dq_results = calwebb_detector1.dq_init_step.DQInitStep.call(groupscale_results, save_results=False)
saturation_results = calwebb_detector1.saturation_step.SaturationStep.call(dq_results, save_results=False)
superbias_results = calwebb_detector1.superbias_step.SuperBiasStep.call(saturation_results, save_results=False)
# Out:
# 2023-10-21 17:29:08,867 - stpipe.GroupScaleStep - INFO - GroupScaleStep instance created.
# 2023-10-21 17:29:08,938 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:29:08,939 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-21 17:29:10,304 - stpipe.GroupScaleStep - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2023-10-21 17:29:10,305 - stpipe.GroupScaleStep - INFO - Step will be skipped
# 2023-10-21 17:29:10,309 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep done
# 2023-10-21 17:29:10,329 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2023-10-21 17:29:10,400 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:29:10,401 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-21 17:29:10,436 - stpipe.DQInitStep - INFO - Using MASK reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_mask_0063.fits
# 2023-10-21 17:29:10,821 - stpipe.DQInitStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:11,564 - stpipe.DQInitStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:13,982 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2023-10-21 17:29:15,623 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:29:15,624 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2023-10-21 17:29:15,646 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2023-10-21 17:29:15,730 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:29:15,731 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}
# 2023-10-21 17:29:15,767 - stpipe.SaturationStep - INFO - Using SATURATION reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0097.fits
# 2023-10-21 17:29:16,299 - stpipe.SaturationStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:17,040 - stpipe.SaturationStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:21,235 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2023-10-21 17:29:38,102 - stpipe.SaturationStep - INFO - Detected 432 saturated pixels
# 2023-10-21 17:29:38,278 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2023-10-21 17:29:38,291 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:29:38,291 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2023-10-21 17:29:38,311 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2023-10-21 17:29:38,387 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:29:38,389 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-21 17:29:38,424 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0142.fits
# 2023-10-21 17:29:38,497 - stpipe.SuperBiasStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:38,545 - stpipe.SuperBiasStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:29:43,539 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:29:43,542 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done

# %% [markdown]
# Let's look at the counts in one of the rows,

# %%
plt.figure(figsize=(15,5))
plt.plot(superbias_results.data[nint,-1,100,:])
plt.ylim([10250,12750])
plt.xlim([512,1536])
plt.xlabel('Column number')
plt.title('Flux measured in the last group of an arbitrary integration in an arbitrary row (for 2nd and 3rd amplifier)')

plt.figure(figsize=(15,5))
plt.plot(superbias_results.data[nint,-1,100,:])
plt.ylim([10250,12250])
plt.xlim([600,700])
plt.xlabel('Column number')
plt.title('Same as above, but zoom-in at columns b/w 600-700 to see the odd-even effect.')
# Out:
# Text(0.5, 1.0, 'Same as above, but zoom-in at columns b/w 600-700 to see the odd-even effect.')

# %% [markdown]
# That's a lot of noise (both odd-even effect noise and offset noise coming from not subtracting background).
#
# Let's see if reference pixel correction step can improve upon this.

# %%
refpix_results = calwebb_detector1.refpix_step.RefPixStep.call(superbias_results, save_results=False)
# Out:
# 2023-10-21 17:29:43,877 - stpipe.RefPixStep - INFO - RefPixStep instance created.
# 2023-10-21 17:29:44,018 - stpipe.RefPixStep - INFO - Step RefPixStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:29:44,020 - stpipe.RefPixStep - INFO - Step RefPixStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2023-10-21 17:29:47,842 - stpipe.RefPixStep - INFO - NIR subarray data
# 2023-10-21 17:29:47,856 - stpipe.RefPixStep - INFO - 4 readout amplifiers used
# 2023-10-21 17:29:47,857 - stpipe.RefPixStep - INFO - The following parameters are valid for this mode:
# 2023-10-21 17:29:47,857 - stpipe.RefPixStep - INFO - odd_even_columns = True
# 2023-10-21 17:29:47,857 - stpipe.RefPixStep - INFO - use_side_ref_pixels = True
# 2023-10-21 17:29:47,858 - stpipe.RefPixStep - INFO - side_smoothing_length = 11
# 2023-10-21 17:29:47,858 - stpipe.RefPixStep - INFO - side_gain = 1.0
# 2023-10-21 17:29:47,859 - stpipe.RefPixStep - INFO - The following parameters are not applicable and are ignored
# 2023-10-21 17:29:47,860 - stpipe.RefPixStep - INFO - odd_even_rows = False
# 2023-10-21 17:32:52,091 - stpipe.RefPixStep - INFO - Step RefPixStep done

# %% [markdown]
# And, did it properly correct for odd-even noise?

# %%
plt.figure(figsize=(15,5))
plt.plot(refpix_results.data[nint,-1,100,:])
plt.ylim([-100,200])
#plt.xlim([512,1536])
plt.xlabel('Column numner')
plt.ylabel('Counts')
plt.title('Flux measured in the last group of an arbitrary integration in an arbitrary row (for 2nd and 3rd amplifier)')

plt.figure(figsize=(15,5))
plt.plot(refpix_results.data[nint,-1,100,:])
plt.ylim([-300,300])
plt.xlim([600,700])
plt.xlabel('Column numner')
plt.ylabel('Counts')
plt.title('Same as above, but zoom-in at columns b/w 600-700 to see the odd-even effect.')
# Out:
# Text(0.5, 1.0, 'Same as above, but zoom-in at columns b/w 600-700 to see the odd-even effect.')

# %% [markdown]
# Looks like most of the odd-even noise is corrected -- however, it seems that background subtraction was not performed properly in the sense that the background level in above data doesn't seem to be correct. So, let' still perform ROEBA background subtraction.

# %%
plt.figure(figsize=(15,5))
im = plt.imshow(refpix_results.data[nint,-1,:,:], interpolation='none')
im.set_clim([-100,2e4])
plt.axvline(0, color='cyan')
plt.axvline(1750, color='cyan')
plt.axhline(15, color='cyan')
plt.axhline(60, color='cyan')
plt.title('Example data frame')
plt.show()

m1 = np.ones(refpix_results.data[nint,-1,:,:].shape)
m1[0:80,0:1750] = 0.

m2 = np.ones(refpix_results.data[nint,-1,:,:].shape)
m2[:,0:1750] = 0.

plt.figure(figsize=(15,5))
plt.imshow(m1, interpolation='none')
plt.title('Mask (M1)')

plt.figure(figsize=(15,5))
plt.imshow(m2, interpolation='none')
plt.title('Mask (M2)')
# Out:
# Text(0.5, 1.0, 'Mask (M2)')

# %% [markdown]
# Okay, so now we will use these mask regions to perform ROEBA-based background subtraction. Basically, we will separately perform background subtraction for each amplifier (there are 4 of them in the detector, each with 512 columns). First we will estimate background for even and odd columns separately and subtract the estimated background from even and odd columns, respectively (background pixels are marked with yellow is M1 mask above). While this will take care of any residual odd-even effect, this will not properly perform a background subtraction. So, in addition to this, we will once again perform column-by-column background subtraction using the same background pixels (yellow in M1 mask). The subtracted background is simply a median of background pixels in a given column.
#
#
# In the end we perform a row-by-row background subtraction --  a same correction for _all_ amplifier since in first three amplifiers there are several rows in mask for which we don't have "background" rows (see, mask M2 in which background pixels are marked with yellow). In this latter step, we simply compute median of the row to find the background.
#
# The algorithm that we will use here is a modified version of what is presented in [Schlawin et al. 2023](https://iopscience.iop.org/article/10.1088/1538-3873/aca718).

# %%
# Computing ROEBA background subtraction on _group_ level
for integration in tqdm(range(refpix_results.data.shape[0])):
    for group in range(refpix_results.data.shape[1]):
        refpix_results.data[integration, group, :, :] = \
            utils.roeba_backgroud_sub(refpix_results.data[integration, group, :, :], m1, fast_read=False)
        # Slow-read (i.e., along the columns) additional correction
        dummy_data = np.copy(refpix_results.data[integration, group, :, :])
        dummy_data[m1 == 0.] = np.nan
        refpix_results.data[integration, group, :, :] = \
            refpix_results.data[integration, group, :, :] - np.nanmedian(dummy_data, axis=0)[None,:]
        # Fast read correction (i.e., along the rows) for all amplifiers
        dummy_data = np.copy(refpix_results.data[integration, group, :, :])
        dummy_data[m2 == 0.] = np.nan
        refpix_results.data[integration, group, :, :] = \
            refpix_results.data[integration, group, :, :] - np.nanmedian(dummy_data, axis=1)[:,None]
# Out:
# 100%|██████████| 65/65 [00:38<00:00,  1.71it/s]

# %%
plt.figure(figsize=(15,5))
plt.plot(refpix_results.data[nint,-1,100,:])
plt.ylim([-100,200])
#plt.xlim([512,1536])
plt.title('Flux measured in the last group of an arbitrary integration in an arbitrary row (for 2nd and 3rd amplifier)')
plt.xlabel('Column Number')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# Awesome! Not only we took care of odd-even noise, but also performed efficient background correction!
#
# Now again continuing with the rest of the steps from the pipeline.

# %%
linearity_results = calwebb_detector1.linearity_step.LinearityStep.call(refpix_results,
                                                                        save_results=False)
darkcurrent_results = calwebb_detector1.dark_current_step.DarkCurrentStep.call(linearity_results,
                                                                            save_results=False)
jumpstep_results = calwebb_detector1.jump_step.JumpStep.call(darkcurrent_results, rejection_threshold=30.,\
                                                             maximum_cores='all', save_results=False)
rampfitting_results = calwebb_detector1.ramp_fit_step.RampFitStep.call(jumpstep_results, maximum_cores='all',\
                                                                       save_results=False)
gainscale_results = calwebb_detector1.gain_scale_step.GainScaleStep.call(rampfitting_results[1],\
                                                                         output_dir=pout, save_results=True)
# Out:
# 2023-10-21 17:33:30,878 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2023-10-21 17:33:31,015 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:33:31,017 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-21 17:33:31,052 - stpipe.LinearityStep - INFO - Using Linearity reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# 2023-10-21 17:33:31,292 - stpipe.LinearityStep - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,293 - stpipe.LinearityStep - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,294 - stpipe.LinearityStep - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,294 - stpipe.LinearityStep - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,295 - stpipe.LinearityStep - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,296 - stpipe.LinearityStep - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:31,296 - stpipe.LinearityStep - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:37,699 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:33:37,701 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2023-10-21 17:33:37,726 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2023-10-21 17:33:37,891 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:33:37,893 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}
# 2023-10-21 17:33:37,928 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_dark_0363.fits
# 2023-10-21 17:33:38,138 - stpipe.DarkCurrentStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:38,187 - stpipe.DarkCurrentStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-21 17:33:38,200 - stpipe.DarkCurrentStep - INFO - Science data nints=65, ngroups=20, nframes=2, groupgap=0
# 2023-10-21 17:33:38,201 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=80, nframes=1, groupgap=0
# 2023-10-21 17:33:45,932 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:33:45,935 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2023-10-21 17:33:45,958 - stpipe - INFO - PARS-JUMPSTEP parameters found: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_pars-jumpstep_0002.asdf
# 2023-10-21 17:33:46,014 - stpipe.jump - INFO - JumpStep instance created.
# 2023-10-21 17:33:46,181 - stpipe.jump - INFO - Step jump running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:33:46,183 - stpipe.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'rejection_threshold': 30.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'all', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'expand_large_events': False, 'find_showers': False, 'edge_size': 25, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200}
# 2023-10-21 17:33:46,200 - stpipe.jump - INFO - CR rejection threshold = 30 sigma
# 2023-10-21 17:33:46,201 - stpipe.jump - INFO - Maximum cores to use = all
# 2023-10-21 17:33:46,223 - stpipe.jump - INFO - Using GAIN reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2023-10-21 17:33:46,315 - stpipe.jump - INFO - Using READNOISE reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0199.fits
# 2023-10-21 17:33:49,927 - stpipe.jump - INFO - Extracting gain subarray to match science data
# 2023-10-21 17:33:51,561 - stpipe.jump - INFO - Executing two-point difference method
# 2023-10-21 17:33:53,221 - stpipe.jump - INFO - Creating 8 processes for jump detection
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2023-10-21 17:34:22,427 - stpipe.jump - INFO - Total elapsed time = 30.8647 sec
# 2023-10-21 17:34:23,313 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:385: RuntimeWarning: invalid value encountered in true_divide
#   data /= gain_2d
#
# 2023-10-21 17:34:24,032 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:386: RuntimeWarning: invalid value encountered in true_divide
#   err /= gain_2d
#
# 2023-10-21 17:34:24,034 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:387: RuntimeWarning: invalid value encountered in true_divide
#   readnoise_2d /= gain_2d
#
# 2023-10-21 17:34:24,093 - stpipe.jump - INFO - The execution time in seconds: 37.893437
# 2023-10-21 17:34:24,105 - stpipe.jump - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:34:24,105 - stpipe.jump - INFO - Step jump done
# 2023-10-21 17:34:24,131 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2023-10-21 17:34:24,274 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:34:24,275 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'all'}
# 2023-10-21 17:34:24,328 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0199.fits
# 2023-10-21 17:34:24,329 - stpipe.RampFitStep - INFO - Using GAIN reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_gain_0097.fits
# 2023-10-21 17:34:24,409 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2023-10-21 17:34:24,411 - stpipe.RampFitStep - INFO - Using algorithm = ols
# 2023-10-21 17:34:24,411 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2023-10-21 17:34:28,383 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:3598: RuntimeWarning: divide by zero encountered in true_divide
#   snr[wh_pos] = data_diff[wh_pos] / sigma_ir[wh_pos]
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# ...
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2023-10-21 17:36:42,999 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:36:43,007 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:36:43,008 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2023-10-21 17:36:43,031 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2023-10-21 17:36:43,187 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(65, 128, 2048) from jw01442001001_04103_00001-seg006_nrcalong_uncal.fits>,).
# 2023-10-21 17:36:43,189 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Volumes/Jayshil/JWST/hat-p-14/NRCLW/Outputs/Tests', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-21 17:36:43,271 - stpipe.GainScaleStep - INFO - GAINFACT not found in gain reference file
# 2023-10-21 17:36:43,272 - stpipe.GainScaleStep - INFO - Step will be skipped
# 2023-10-21 17:36:43,281 - stpipe.GainScaleStep - INFO - Results used CRDS context: jwst_1141.pmap
# 2023-10-21 17:36:43,938 - stpipe.GainScaleStep - INFO - Saved model in /Volumes/Jayshil/JWST/hat-p-14/NRCLW/Outputs/Tests/jw01442001001_04103_00001-seg006_nrcalong_gainscalestep.fits
# 2023-10-21 17:36:43,938 - stpipe.GainScaleStep - INFO - Step GainScaleStep done

# %% [markdown]
# Let's look at the mask:

# %%
dq = rampfitting_results[1].dq
mask = np.ones(dq.shape)
mask[dq > 0] = 0.

print('Total per cent of masked points: {:.4f} %'.format(100 * (1 - np.sum(mask) / (mask.shape[0] * mask.shape[1] * mask.shape[2]))))

plt.figure(figsize=(15,5))
plt.imshow(mask[nint,:,:], interpolation='none')
plt.title('Bad-pixels for an arbitrary integration')
#plt.xlim([512,1536])
# Out:
# Total per cent of masked points: 4.8602 %
# Text(0.5, 1.0, 'Bad-pixels for an arbitrary integration')

# %% [markdown]
# Okay, so there are less than 1% of pixels masked as "bad" -- not a huge number.
#
# And this is how the data looks like,

# %%
plt.figure(figsize=(15,5))
plt.imshow(gainscale_results.data[nint,:,:], interpolation='none')
plt.title('Example data frame')
# Out:
# Text(0.5, 1.0, 'Example data frame')

# %%
plt.figure(figsize=(15,5))
plt.plot(gainscale_results.data[nint,100,:])
#plt.axvline(1536, color='k')
plt.axhline(0., color='k')
plt.xlabel('Column number')
plt.ylabel('Counts')
plt.title('Flux level in an arbitrary row of an arbitrary integration')
# Out:
# Text(0.5, 1.0, 'Flux level in an arbitrary row of an arbitrary integration')

# %%
plt.figure(figsize=(15,5))
plt.plot(gainscale_results.data[nint,:,500])
plt.ylim([-2.5,2.5])
plt.axhline(0., color='k')
plt.xlabel('Row number')
plt.ylabel('Counts')
plt.title('Flux level in an arbitrary column of an arbitrary integration')
# Out:
# Text(0.5, 1.0, 'Flux level in an arbitrary column of an arbitrary integration')

# %% [markdown]
# Okay, so most of all odd-even effect and amplifier effect were removed effectively. However, I see that the count level in a background row (see, above figure) is slightly below zero, meaning that we need an additional row-by-row background correction which we will perform after "correcting" the data.
#
# And, finally, correct the data. Starting with correcting the errorbars,

# %%
times_bjd = uncal.int_times['int_mid_BJD_TDB']

print('>>>> --- Correcting errorbars (for zeros and NaNs)...')
## Correct errorbars
med_err = np.nanmedian(gainscale_results.err.flatten())
## Changing Nan's and zeros in error array with median error
corr_err1 = np.copy(gainscale_results.err)
corr_err2 = np.where(gainscale_results.err != 0., corr_err1, med_err)                     # Replacing error == 0 with median error
corrected_errs = np.where(np.isnan(gainscale_results.err) != True, corr_err2, med_err)    # Replacing error == Nan with median error
print('>>>> --- Done!!')
# Out:
# >>>> --- Correcting errorbars (for zeros and NaNs)...
# >>>> --- Done!!

# %% [markdown]
# And creating a bad-pixel map (this is in addition to the bad-pixel map we already have -- the idea is to include all those pixels with 0 or NaN errors in bad pixel map. Additionally, we will manually identify cosmic rays by comparing median frame with each frame and add those pixels in the bad-pixel map),

# %%
print('>>>> --- Creating a bad-pixel map...')
## Making a bad-pixel map
mask_bp1 = np.ones(gainscale_results.data.shape)
mask_bp2 = np.where(gainscale_results.err != 0., mask_bp1, 0.)                 # This will place 0 in mask where errorbar == 0
mask_bp3 = np.where(np.isnan(gainscale_results.err) != True, mask_bp2, 0.)     # This will place 0 in mask where errorbar is Nan
#mask_badpix = np.where(dq == 0., mask_bp3, 0.)                               # This will place 0 in mask where darkdq != 0
mask_badpix = mask * mask_bp3                                                 # Adding those pixels which are identified as bad by the pipeline (and hence 0)

## Mask with cosmic rays
### Essentially this mask will add 0s in the places of bad pixels...
mask_bcr = utils.identify_crays(gainscale_results.data, mask_badpix)
print('>>>> --- Done!!')
# Out:
# >>>> --- Creating a bad-pixel map...
# >>>> --- Done!!

# %%
print('Total per cent of masked points: {:.4f} %'.format(100 * (1 - np.sum(mask_bcr) / (mask_bcr.shape[0] * mask_bcr.shape[1] * mask_bcr.shape[2]))))

plt.figure(figsize=(15,5))
plt.imshow(mask_bcr[nint,:,:], interpolation='none')
plt.title('Bad-pixels for an arbitrary integration')
#plt.xlim([512,1536])
# Out:
# Total per cent of masked points: 4.8883 %
# Text(0.5, 1.0, 'Bad-pixels for an arbitrary integration')

# %% [markdown]
# And correct the data (meaning replacing NaN values in data-frame with average of neighbouring pixels),

# %%
print('>>>> --- Correcting data...')
corrected_data = np.copy(gainscale_results.data)
corrected_data[mask_bcr == 0] = np.nan
for i in range(corrected_data.shape[0]):
    corrected_data[i,:,:] = utils.replace_nan(corrected_data[i,:,:])
print('>>>> --- Done!!')
# Out:
# >>>> --- Correcting data...
# >>>> --- Done!!

# %% [markdown]
# And, finally, we will perform a row-by-row background subtraction:

# %%
corrected_data_bkg1 = np.ones(corrected_data.shape)
for i in tqdm(range(corrected_data.shape[0])):
    corrected_data_bkg1[i,:,:], _ = reduce.row_by_row_bkg_sub(corrected_data[i,:,:], mask=m2*mask_bcr[i,:,:])
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]2023-10-21 17:37:11,211 - stpipe - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#
# 100%|██████████| 65/65 [00:00<00:00, 109.91it/s]

# %%
plt.figure(figsize=(15,5))
plt.plot(corrected_data_bkg1[nint,100,:])
plt.ylim([-2,2])
plt.axhline(0., color='k')
#plt.axvline(1536., color='k')
plt.title('Flux measured in an arbitrary row of an arbitrary integration')
plt.xlabel('Column number')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# Saving the data,

# %%
np.save(pout + '/Corrected_data.npy', corrected_data_bkg1)
np.save(pout + '/Corrected_err.npy', corrected_errs)
np.save(pout + '/Mask_bcr.npy', mask_bcr)
np.save(pout + '/times.npy', times_bjd)
