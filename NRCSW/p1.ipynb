# %% [markdown]
# # Performing aperture photometry to extract NIRCam SW data
#
# In this notebook, we will produce corrected data from `uncal` JWST data.
#
# For stage 1 processing, we will mainly use the `jwst` pipeline with some modifications. The main modification is the use of `refpix` step. Since the data only have reference pixels on the side of the detector, the `refpix` step will not properly correct for the odd-even effect. Therefore, we have replaced `refpix` step with group level background subtraction using ROEBA (row-by-row odd/even by amplifier correction, [Schlawin et al. 2023](https://iopscience.iop.org/article/10.1088/1538-3873/aca718)) algorithm. We also skip the `dark_current` step. After this step we will proceed as usual using `jwst` pipeline.

# %%
import numpy as np
import matplotlib.pyplot as plt
from jwst import datamodels
from jwst.pipeline import calwebb_detector1
from tqdm import tqdm
import os
import utils

# %%
p1 = '/'.join(os.getcwd().split('/')[:-1])
pin = p1 + '/Data/NRC_SW'
pout = p1 + '/NRCSW/Outputs/Tests'

fname = 'jw01442001001_04103_00001-seg006_nrca3_uncal.fits'

# %% [markdown]
# ## calwebb detector 1 processing

# %%
uncal = datamodels.RampModel(pin + '/' + fname)
nint = np.random.randint(0, uncal.data.shape[0])

print(uncal)
# Out:
# <RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>

# %% [markdown]
# Meaning that the data has 65 total integration and 20 groups per integrations. An individual frame has 128 by 2048 pixels (128 rows and 2048 columns).
#
# Let's perform `groupscale`, `dq`, `saturation` and `superbias` steps manually.

# %%
"""det1 = calwebb_detector1.Detector1Pipeline.call(uncal,\
                                                steps={'jump' : {'rejection_threshold' : 20., 'maximum_cores': 'all'},\
                                                       'dark_current' : {'skip' : True},\
                                                       'ramp_fit' : {'maximum_cores' : 'all'}},\
                                                output_dir=pout, save_results=True)"""

# I tried running the pipeline collectively, but it turns out that the jump step was flagging many pixels
# wrongly; maybe this is because of improper reference pixel correction step -- so now, I will manually perform
# this step using ROEBA algorithm.

groupscale_results = calwebb_detector1.group_scale_step.GroupScaleStep.call(uncal, save_results=False)
dq_results = calwebb_detector1.dq_init_step.DQInitStep.call(groupscale_results, save_results=False)
saturation_results = calwebb_detector1.saturation_step.SaturationStep.call(dq_results, save_results=False)
superbias_results = calwebb_detector1.superbias_step.SuperBiasStep.call(saturation_results, save_results=False)
# Out:
# 2023-10-16 23:07:43,753 - stpipe.GroupScaleStep - INFO - GroupScaleStep instance created.
# 2023-10-16 23:07:43,804 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:07:43,805 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-16 23:07:46,106 - stpipe.GroupScaleStep - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2023-10-16 23:07:46,108 - stpipe.GroupScaleStep - INFO - Step will be skipped
# 2023-10-16 23:07:46,111 - stpipe.GroupScaleStep - INFO - Step GroupScaleStep done
# 2023-10-16 23:07:46,127 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2023-10-16 23:07:46,232 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:07:46,233 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-16 23:07:46,261 - stpipe.DQInitStep - INFO - Using MASK reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_mask_0067.fits
# 2023-10-16 23:07:46,428 - stpipe.DQInitStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:07:46,655 - stpipe.DQInitStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:07:49,595 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2023-10-16 23:07:51,193 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:07:51,193 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2023-10-16 23:07:51,209 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2023-10-16 23:07:51,299 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:07:51,300 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}
# 2023-10-16 23:07:51,321 - stpipe.SaturationStep - INFO - Using SATURATION reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0096.fits
# 2023-10-16 23:07:51,461 - stpipe.SaturationStep - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:07:51,680 - stpipe.SaturationStep - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:07:54,231 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2023-10-16 23:08:04,110 - stpipe.SaturationStep - INFO - Detected 141 saturated pixels
# 2023-10-16 23:08:04,236 - stpipe.SaturationStep - INFO - Detected 1 A/D floor pixels
# 2023-10-16 23:08:04,246 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:08:04,246 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2023-10-16 23:08:04,261 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2023-10-16 23:08:04,355 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:08:04,356 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-16 23:08:04,377 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0027.fits
# 2023-10-16 23:08:04,521 - stpipe.SuperBiasStep - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:07,995 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:08:07,995 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done

# %% [markdown]
# Let's look at the counts in one of the rows,

# %%
plt.figure(figsize=(15,5))
plt.plot(superbias_results.data[nint,-1,60,512:1536])
plt.ylim([5500,7500])
# Out:
# (5500.0, 7500.0)

# %% [markdown]
# That's a lot of noise (both odd-even effect noise and without background subtraction).
#
# Let's now define the background region -- we will use background pixels to estimate background and then subtract it.

# %%
plt.figure(figsize=(15,5))
im = plt.imshow(superbias_results.data[0,-1,:,:], interpolation='none')
im.set_clim([-100,10000])
plt.axvline(1060-200, color='k')
plt.axvline(1060+200, color='k')
plt.xlim([512,1536])
plt.title('Example data frame')
plt.show()

m1 = np.ones(superbias_results.data[0,-1,:,:].shape)
m1[:,1060-200:1060+200] = 0.

plt.figure(figsize=(15,5))
plt.imshow(m1, interpolation='none')
plt.title('Mask')
plt.xlim([512,1536])
# Out:
# (512.0, 1536.0)

# %% [markdown]
# Okay, so now we will use this mask region to perform ROEBA-based background subtraction. Basically, we will separately perform background subtraction for each amplifier. First we will estimate background for even and odd columns separately and subtract the estimated background from even and odd columns, respectively. In the end we perform a row-by-row background subtraction. In this latter step, we simply compute median of the row to find the background.

# %%
# Computing ROEBA background subtraction on _group_ level
for integration in tqdm(range(superbias_results.data.shape[0])):
    for group in range(superbias_results.data.shape[1]):
        superbias_results.data[integration, group, :, :] = \
            utils.roeba_backgroud_sub(superbias_results.data[integration, group, :, :], m1)
# Out:
# 100%|██████████| 65/65 [00:22<00:00,  2.93it/s]

# %%
plt.figure(figsize=(15,5))
plt.plot(superbias_results.data[nint,-1,60,512:1536])
plt.ylim([-100,200])
#plt.xlim([100,200])
# Out:
# (-100.0, 200.0)

# %% [markdown]
# Awesome! Not only we took care of odd-even noise, but also performed efficient background correction!
#
# Let's again plot the data to see how well we did,

# %%
plt.figure(figsize=(15,5))
im = plt.imshow(superbias_results.data[0,-1,:,:], interpolation='none')
im.set_clim([-100,5000])
plt.axvline(1060-200, color='k')
plt.axvline(1060+200, color='k')
plt.xlim([512,1536])
plt.title('Example data frame')
plt.show()

# %% [markdown]
# Perfect! And now again continuing with the rest of the steps from the pipeline.

# %%
linearity_results = calwebb_detector1.linearity_step.LinearityStep.call(superbias_results,
                                                                        save_results=False)
#darkcurrent_results = calwebb_detector1.dark_current_step.DarkCurrentStep.call(linearity_results,
#                                                                            save_results=False)
jumpstep_results = calwebb_detector1.jump_step.JumpStep.call(linearity_results, rejection_threshold=10.,\
                                                             maximum_cores='all', save_results=False)
rampfitting_results = calwebb_detector1.ramp_fit_step.RampFitStep.call(jumpstep_results, maximum_cores='all',\
                                                                       save_results=False)
gainscale_results = calwebb_detector1.gain_scale_step.GainScaleStep.call(rampfitting_results[1],\
                                                                         save_results=False)
# Out:
# 2023-10-16 23:08:30,738 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2023-10-16 23:08:30,832 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:08:30,833 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-16 23:08:30,854 - stpipe.LinearityStep - INFO - Using Linearity reference file /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0053.fits
# 2023-10-16 23:08:31,015 - stpipe.LinearityStep - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,016 - stpipe.LinearityStep - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,016 - stpipe.LinearityStep - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,017 - stpipe.LinearityStep - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,017 - stpipe.LinearityStep - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,018 - stpipe.LinearityStep - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:31,018 - stpipe.LinearityStep - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-10-16 23:08:35,303 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:08:35,306 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2023-10-16 23:08:35,323 - stpipe - INFO - PARS-JUMPSTEP parameters found: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_pars-jumpstep_0002.asdf
# 2023-10-16 23:08:35,351 - stpipe.jump - INFO - JumpStep instance created.
# 2023-10-16 23:08:35,535 - stpipe.jump - INFO - Step jump running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:08:35,537 - stpipe.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'rejection_threshold': 10.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'all', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'expand_large_events': False, 'find_showers': False, 'edge_size': 25, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200}
# 2023-10-16 23:08:35,547 - stpipe.jump - INFO - CR rejection threshold = 10 sigma
# 2023-10-16 23:08:35,548 - stpipe.jump - INFO - Maximum cores to use = all
# 2023-10-16 23:08:35,561 - stpipe.jump - INFO - Using GAIN reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_gain_0091.fits
# 2023-10-16 23:08:35,621 - stpipe.jump - INFO - Using READNOISE reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits
# 2023-10-16 23:08:37,611 - stpipe.jump - INFO - Extracting gain subarray to match science data
# 2023-10-16 23:08:37,612 - stpipe.jump - INFO - Extracting readnoise subarray to match science data
# 2023-10-16 23:08:38,577 - stpipe.jump - INFO - Executing two-point difference method
# 2023-10-16 23:08:39,940 - stpipe.jump - INFO - Creating 8 processes for jump detection
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/twopoint_difference.py:154: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# 2023-10-16 23:08:53,959 - stpipe.jump - INFO - Total elapsed time = 15.3812 sec
# 2023-10-16 23:08:54,558 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:385: RuntimeWarning: invalid value encountered in true_divide
#   data /= gain_2d
#
# 2023-10-16 23:08:55,015 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:386: RuntimeWarning: invalid value encountered in true_divide
#   err /= gain_2d
#
# 2023-10-16 23:08:55,016 - stpipe.jump - WARNING - /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/jump/jump.py:387: RuntimeWarning: invalid value encountered in true_divide
#   readnoise_2d /= gain_2d
#
# 2023-10-16 23:08:55,061 - stpipe.jump - INFO - The execution time in seconds: 19.513525
# 2023-10-16 23:08:55,069 - stpipe.jump - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:08:55,069 - stpipe.jump - INFO - Step jump done
# 2023-10-16 23:08:55,087 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2023-10-16 23:08:55,189 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(65, 20, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:08:55,190 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'all'}
# 2023-10-16 23:08:55,226 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0030.fits
# 2023-10-16 23:08:55,227 - stpipe.RampFitStep - INFO - Using GAIN reference file: /Users/japa6985/crds_cache/references/jwst/nircam/jwst_nircam_gain_0091.fits
# 2023-10-16 23:08:55,286 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2023-10-16 23:08:55,287 - stpipe.RampFitStep - INFO - Extracting readnoise subarray to match science data
# 2023-10-16 23:08:55,287 - stpipe.RampFitStep - INFO - Using algorithm = ols
# 2023-10-16 23:08:55,287 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2023-10-16 23:08:58,060 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# ...
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# /Users/japa6985/opt/anaconda3/envs/jwst/lib/python3.9/site-packages/stcal/ramp_fitting/ols_fit.py:1133: RuntimeWarning: invalid value encountered in multiply
#   var_p4[num_int, :, :, :] *= (segs_4[num_int, :, :, :] > 0)
# 2023-10-16 23:10:09,133 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:10:09,139 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:10:09,139 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2023-10-16 23:10:09,154 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2023-10-16 23:10:09,256 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(65, 128, 2048) from jw01442001001_04103_00001-seg006_nrca3_uncal.fits>,).
# 2023-10-16 23:10:09,257 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-10-16 23:10:09,309 - stpipe.GainScaleStep - INFO - GAINFACT not found in gain reference file
# 2023-10-16 23:10:09,310 - stpipe.GainScaleStep - INFO - Step will be skipped
# 2023-10-16 23:10:09,315 - stpipe.GainScaleStep - INFO - Results used CRDS context: jwst_1140.pmap
# 2023-10-16 23:10:09,315 - stpipe.GainScaleStep - INFO - Step GainScaleStep done

# %% [markdown]
# Let's look at the mask:

# %%
dq = rampfitting_results[1].dq
mask = np.ones(dq.shape)
mask[dq > 0] = 0.

print('Total per cent of masked points: {:.4f} %'.format(100 * (1 - np.sum(mask) / (mask.shape[0] * mask.shape[1] * mask.shape[2]))))

plt.figure(figsize=(15,5))
plt.imshow(mask[nint,:,512:1536], interpolation='none')
# Out:
# Total per cent of masked points: 0.8985 %

# %% [markdown]
# And this is how the data looks like,

# %%
plt.figure(figsize=(15,5))
plt.imshow(gainscale_results.data[nint,:,512:1536], interpolation='none')

# %% [markdown]
# And, finally, correct the data. Starting with correcting the errorbars,

# %%
times_bjd = uncal.int_times['int_mid_BJD_TDB']

print('>>>> --- Correcting errorbars (for zeros and NaNs)...')
## Correct errorbars
med_err = np.nanmedian(gainscale_results.err.flatten())
## Changing Nan's and zeros in error array with median error
corr_err1 = np.copy(gainscale_results.err)
corr_err2 = np.where(gainscale_results.err != 0., corr_err1, med_err)                     # Replacing error == 0 with median error
corrected_errs = np.where(np.isnan(gainscale_results.err) != True, corr_err2, med_err)    # Replacing error == Nan with median error
print('>>>> --- Done!!')
# Out:
# >>>> --- Correcting errorbars (for zeros and NaNs)...
# >>>> --- Done!!

# %% [markdown]
# And creating a bad-pixel map,

# %%
print('>>>> --- Creating a bad-pixel map...')
## Making a bad-pixel map
mask_bp1 = np.ones(gainscale_results.data.shape)
mask_bp2 = np.where(gainscale_results.err != 0., mask_bp1, 0.)                 # This will place 0 in mask where errorbar == 0
mask_bp3 = np.where(np.isnan(gainscale_results.err) != True, mask_bp2, 0.)     # This will place 0 in mask where errorbar is Nan
mask_badpix = np.where(dq == 0., mask_bp3, 0.)                               # This will place 0 in mask where darkdq != 0
## Mask with cosmic rays
### Essentially this mask will have 0s in the places of bad pixels...
mask_bcr = utils.identify_crays(gainscale_results.data, mask_badpix)
print('>>>> --- Done!!')
# Out:
# >>>> --- Creating a bad-pixel map...
# >>>> --- Done!!

# %%
print('Total per cent of masked points: {:.4f} %'.format(100 * (1 - np.sum(mask_bcr) / (mask_bcr.shape[0] * mask_bcr.shape[1] * mask_bcr.shape[2]))))

plt.figure(figsize=(15,5))
plt.imshow(mask_bcr[nint,:,512:1536], interpolation='none')
# Out:
# Total per cent of masked points: 0.9057 %

# %% [markdown]
# And correct the data,

# %%
print('>>>> --- Correcting data...')
corrected_data = np.copy(gainscale_results.data)
corrected_data[mask_bcr == 0] = np.nan
for i in range(corrected_data.shape[0]):
    corrected_data[i,:,:] = utils.replace_nan(corrected_data[i,:,:])
print('>>>> --- Done!!')
# Out:
# >>>> --- Correcting data...
# >>>> --- Done!!

# %%
plt.figure(figsize=(15,5))
plt.imshow(corrected_data[nint,:,512:1536], interpolation='None')

# %%
plt.figure(figsize=(15,5))
plt.plot(gainscale_results.data[nint,60,512:1536])
plt.ylim([-1,1])
# Out:
# (-1.0, 1.0)

# %% [markdown]
# Saving the data,

# %%
np.save(pout + '/Corrected_data.npy', corrected_data[:,:,512:1536])
np.save(pout + '/Corrected_err.npy', corrected_errs[:,:,512:1536])
np.save(pout + '/Mask_bcr.npy', mask_bcr[:,:,512:1536])
np.save(pout + '/times.npy', times_bjd)
